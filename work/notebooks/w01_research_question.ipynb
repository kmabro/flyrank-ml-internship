# %% [markdown]
# <a href="https://colab.research.google.com/github/kmabro/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kmabro/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ### Lane 2: Refresh / Content Opportunity Scoring
#
# I chose this lane because the starter data contains observable signals such as impressions, freshness, position, CTR, and content characteristics that can help prioritize pages for review. The goal is not to guarantee that a page will recover after a refresh, but to identify which pages should be reviewed first. I can start with a transparent rule and later test whether a simple ML model can produce a more useful ranking.

# %%
# @title
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Lane: Refresh / Content Opportunity Scoring")
print("Unit of analysis: One content page")
print("Goal: Prioritize pages for human review")
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Unit of analysis: One content page
# Goal: Prioritize pages for human review

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ### The question
#
# **Research question:** Which pages should be reviewed first for a potential content refresh based on observable search and content signals?
#
# **Decision:** Decide which pages should receive limited content-review resources first.
#
# **Action:** A reviewer can inspect the highest-ranked pages and decide whether to refresh, expand, protect, prune, or monitor them.
#
# **Unit of analysis:** One content page.
#
# **Output:** A ranked list of pages with a score, suggested action, and reason codes.
#
# **Cost of a wrong recommendation:** A false positive can waste a reviewer's time on a page that does not need attention. A false negative can cause a potentially useful page to be overlooked. Therefore, the ranking should be evaluated carefully rather than treated as a guarantee.
#
# **Why data/ML can help:** The data contains multiple observable signals about visibility, freshness, position, CTR, engagement, and content characteristics. A model may combine these signals more effectively than a single hand-written rule.

# %%
# @title
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Decision: Which pages should receive review resources first?")
print("Action: Review, refresh, expand, protect, prune, or monitor selected pages")
print("Unit of analysis: One content page")
print("Output: Ranked review list with score and reason codes")
# Out:
# Decision: Which pages should receive review resources first?
# Action: Review, refresh, expand, protect, prune, or monitor selected pages
# Unit of analysis: One content page
# Output: Ranked review list with score and reason codes

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# ### Quick look at the data
#
# I will use the starter dataset to check how many pages are available, how many are currently marked as declining, and how many have meaningful search exposure. These numbers will help determine whether there is enough variation in the data to investigate a page-prioritization problem.

# %%
# @title
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/kmabro/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("Declining pages:",
      (df["trend_direction"].str.lower() == "down").sum())

print("Pages with 500+ impressions:",
      (df["impressions_90d"] >= 500).sum())
# Out:
# Rows: 30000
# Columns: 44
# Declining pages: 16262
# Pages with 500+ impressions: 16726

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ### What I can and cannot claim
#
# **What I can claim:** I can identify associations between observable page signals and the outcome in this dataset, and I can test whether a ranking method performs better than a simple baseline.
#
# **What I cannot claim:** I cannot claim that a particular signal causes Google rankings to change, or that refreshing a page will definitely recover its traffic. The data is observational, so the results should be treated as directional evidence for prioritizing review.
#
# I will also avoid using future information as model features and will check for leakage during later modeling.

# %%
# @title
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claims: observed associations and measured ranking performance")
print("Use: directional decision-support")
print("Not claimed: causal proof or prediction of Google rankings")
# Out:
# Claims: observed associations and measured ranking performance
# Use: directional decision-support
# Not claimed: causal proof or prediction of Google rankings

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/`
